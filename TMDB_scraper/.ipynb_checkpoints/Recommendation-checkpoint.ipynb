# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv").drop_duplicates()

# %%
df_1 = pd.DataFrame(df.movie_or_TV_name.value_counts()).reset_index()
df_1.columns = ['movie','number_of_shared_actors']
df_1 = df_1[:10]
df_1
# Out:
#                             movie  number_of_shared_actors
# 0                  The Last of Us                       47
# 1                    Supernatural                        9
# 2                           Arrow                        8
# 3                          Nikita                        5
# 4  CSI: Crime Scene Investigation                        5
# 5                       The Flash                        4
# 6                      Smallville                        4
# 7                           Psych                        3
# 8                   Stargate SG-1                        3
# 9                 The Good Doctor                        3

# %%
import matplotlib.pyplot as plt

plt.pie(df_1["number_of_shared_actors"], labels = df_1["movie"],wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' })
plt.title("The number of shared actors proportion in top 10 recommended movies")
plt.show()
